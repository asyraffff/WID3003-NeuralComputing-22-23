# %% [markdown]
# # Announcement
#
# A few students commented that the downloaded model effectively crashed their gpus/cpus, and was not able to train the model. Well, that was one of the objective anyway, for you to experience how huge state of the art (sota) models and their parameters are. GPT3 is said to have around 175 BILLION parameters.
#
# So if your GPU crashed, or you are not able to train the model, YOU ARE ALLOWED TO USE ONLINE MODELS (via huggingface ) . But just using those models is just too easy. So YOU HAVE TO BE CREATIVE and show more effort.
#
#
#
# # 3. Explore/Play around with Text to Image Generation and/or Large Language Models (LLMs)
#
#
#
#
# The hottest Deep Learning models are (as you already know) the Large Language models,  (LLMs,most famous platform is the ChaptGPT) and Text to image generation (most famous platform is Midjourney, currently at version 5)
#
# LLMS are mainly based on BERT, GPT , LLaMa(Meta AI) which are mainly based on the transformer models. Text to image genearations originates mainly from 2, the first one is Stable Diffussion, and the second one is DALL-E
#
# Open AI platform uses GPT for LLMS(Chat GPT) and DALL-E for Text to image generation. There is a rumour that GPT-5 will be available by the end of the year, but nothing is confirmed yet. The free version that you are using on Open AI is GPT-3.5. Midjourney is said by Stable Diffussion models, whereby the actual model is undiclosed to public, for obvious reasons. So we don't know for sure.
#
# You can have some access to Stable Diffussion version 2.1 via HuggingFace and play around in colab. But access to GPT by Open AI would require API keys which costs money. You can generate API keys with the free plan, but it Open AI won't allow you to run GPT-3.5 with that
#
#
# ## Instructions
#
# ###1. Find an open source code for LLM and/or Text to Image Generation
#
# Find models that you can run locally (if you have GPUs) or using colab. It will be the case that running using colab isn't very realistic at this point since we are dealing with huge models. I think you'll find that finding models that can fit your local machine is quite challenging. But there are researchers that replicates the famous models and made them online. Some of the references for finding them would be
#
# https://paperswithcode.com/
#
#
# Andrej Karpathy did a nanoGPT (he is quite a legend himself) :https://github.com/karpathy/nanoGPT
#
# Meta AI also revealed their own LLMS. It's supposed to be open source: https://ai.facebook.com/blog/large-language-model-llama-meta-ai/
#
#
# Somebody did a gpt that can be run on local machine: https://gpt4all.io/index.html
#
# Here are the links to Stable diffussion models
#
#
# https://github.com/Stability-AI/stablediffusion
#
# https://huggingface.co/stabilityai/stable-diffusion-2-1
#
#
#
# ###2. Play around, explore the codes, be creative.
#
# But just running somebody else's code is too easy and boring. So please do either 2.1 or 2.2 below. You can do both if you want to.
#
# ####2.1 Use your own dataset, fine tune.
#
# This is straightforward but sometimes difficult to do. You will need to use some local dataset, and train the open source models that you have found.
#
# One idea is to scrap the web for stable diffussion/ midjourney pics or AI generated images, and build a simple binary classifier to classify whether a picture is a 'AI generate image' or 'Non-AI generated image'.
#
# ####2.2 Built some plugins, or demonstrate how you can merge the two technologies.
#
# Here I would like to see your creativity. For example, I think it is plausible to create a whole website for an online [x] store using GPT+Diffussion models. Let's say x is cookie. You can
#
# 1. Code website for the online cookie store-generate code from GPT
# 2. Create a range of cookies selection-generate from GPT
# 3. Generate pictures of the ranges of cookies-Stable Diffussion
# 4. Create the theme/color of the website-GPT
# 5. Design the overall look of the website/Mockup- Stable Diffussion
# 6. Design the cookie name - GPT
# 7. Design the cookie logo- Stable Diffussion
# 8. Generate Copywriting for the cookies -GPT
#
#
# One way of being creative is to use the output of the trained model as input to another model. I used GPT to come up with the prompt for the cookie selection and their names. And then I used those prompts to generate a picture of the cookie selections.

# %% [markdown]
# 'Mango Sticky Rice Cookies'- this is what GPT suggested me
#
# And below is what Stable-Diffussion 2.1 generated.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# What are the prompts to produce prompts for cookies? That for now is a trade secret....You might benefit learning Prompt Engineering as well from
#
# https://www.deeplearning.ai/short-courses/chatgpt-prompt-engineering-for-developers/
#
#
# ###3. Write a documentation report (2~3 pages)
#
# Document your work as instructions of how you did what you did. Last but not least....
#
#
# #You will be evaluated on your effort and creativity, not on your model performances.
